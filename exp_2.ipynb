# %% [markdown]
# <a href="https://colab.research.google.com/github/krithika168/wpt2/blob/main/exp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data={
    'First':['Aryan','Rohon','Riya','Yash','Siddini'],
    'Lastname':['Singh','Agarwal','Shah','Batia','Khan'],
    'Type':['Full_time employee','Intern','Full_time employee','Part time employee','Full_time employee'],
    'Department':['Administration','Technical','Administration','Technical','Technical'],
    'Yoe':[2,3,5,7,6],
    'Salary':[20000,5000,10000,20000,30000]
    }
df=pd.DataFrame(data)
print(df)
table=pd.pivot_table(df,index=['Type','Department'],values='Salary',aggfunc=['mean'])
print(table)
table1=pd.pivot_table(df,index=['Type'],values='Salary',aggfunc=['sum','mean'])
print(table1)
table2=pd.pivot_table(df,index=['Type'],values='Salary',aggfunc=['count'])
print(table2)
table3=pd.pivot_table(df,index=['Type'],values='Salary',aggfunc=['std'])
print(table3)
# Out:
#      First Lastname                Type      Department  Yoe  Salary
# 0    Aryan    Singh  Full_time employee  Administration    2   20000
# 1    Rohon  Agarwal              Intern       Technical    3    5000
# 2     Riya     Shah  Full_time employee  Administration    5   10000
# 3     Yash    Batia  Part time employee       Technical    7   20000
# 4  Siddini     Khan  Full_time employee       Technical    6   30000
#                                       mean
#                                     Salary
# Type               Department
# Full_time employee Administration  15000.0
#                    Technical       30000.0
# Intern             Technical        5000.0
# Part time employee Technical       20000.0
#                       sum     mean
#                    Salary   Salary
# Type
# Full_time employee  60000  20000.0
# Intern               5000   5000.0
# Part time employee  20000  20000.0
#                     count
#                    Salary
# Type
# Full_time employee      3
# Intern                  1
# Part time employee      1
#                         std
#                      Salary
# Type
# Full_time employee  10000.0
